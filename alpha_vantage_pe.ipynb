# %%
# !pip install alpha_vantage
# !pip install alpha_vantage --upgrade

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-96ae26aa-c4be-4e55-9ccc-582d32e2a6f7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96ae26aa-c4be-4e55-9ccc-582d32e2a6f7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd
data=io.BytesIO(uploaded['nasdaq_screener_1703224715886.csv'])

# %%
from alpha_vantage.timeseries import TimeSeries
key= '5PGZXNVQFYJOCG18'
outputsize= 'compact'
comp=input('Ticker: ')
typ=input( 'Type :"Daily", "weekly", "monthly", ""interval" ')

ts=TimeSeries(key, output_format='pandas')


if typ=='daily':
  state = ts.get_daily_adjusted(comp, outputsize=outputsize)[0]
elif typ=='weekly':
  state= ts.get_weekly_adjusted(comp)[0]
elif typ=='monthly':
  state=ts.get_monthly_adjusted(comp)[0]
elif typ=='interval':
  interval=input('interval: 1min, 15min, 30min, 60min: ')
  state=ts.get_intraday(comp, interval=interval, outputsize=outputsize)[0]
else:
  print('wrong entry')
state
# Out:
# Ticker: msft
# Type :"Daily", "weekly", "monthly", ""interval" interval
# interval: 1min, 15min, 30min, 60min: 15min
#                      1. open  2. high   3. low  4. close  5. volume
# date
# 2023-12-20 19:45:00  371.260   371.30  371.000   371.000     8159.0
# 2023-12-20 19:30:00  371.301   371.41  371.260   371.260     4289.0
# 2023-12-20 19:15:00  371.300   371.44  371.280   371.300     1991.0
# 2023-12-20 19:00:00  371.350   371.35  370.620   371.280    65083.0
# 2023-12-20 18:45:00  371.020   371.35  371.000   371.350     1877.0
# ...                      ...      ...      ...       ...        ...
# 2023-12-19 12:00:00  371.960   371.96  371.290   371.550   327709.0
# 2023-12-19 11:45:00  372.590   372.70  371.745   371.930   322104.0
# 2023-12-19 11:30:00  372.330   372.72  372.130   372.580   383221.0
# 2023-12-19 11:15:00  372.110   372.64  371.940   372.330   424988.0
# 2023-12-19 11:00:00  371.660   372.17  371.360   372.103   414243.0
#
# [100 rows x 5 columns]

# %%
from alpha_vantage.fundamentaldata import FundamentalData
from alpha_vantage.sectorperformance import SectorPerformances
from alpha_vantage.timeseries import TimeSeries
from pprint import pprint
key= 'MFD85QIHD106NLRK'
fd=FundamentalData(key, output_format='pandas')
sp = SectorPerformances(key, output_format='pandas')
df=pd.read_csv('nasdaq_screener_1703224715886.csv')
sec=['Finance']
fin=[]
fin_sym=[]
fin_vol=[]
last_sale=[]
n=0
for i in sec:
  fin.extend(df[df['Sector']==i]['Name'].tolist()[:5])
  fin_sym.extend(df[df['Sector']==i]['Symbol'].tolist()[:5])
  fin_vol.extend(df[df['Sector']==i]['Volume'].tolist()[:5])
  last_sale.extend(df[df['Sector']==i]['Last Sale'].tolist()[:5])
  n=n+1
pprint(fin)
pprint(fin_sym)
i=0
pe_ratio_comparision=[]
while i<=n:
  symbol=fin_sym[i]
  volume=fin_vol[i]
  market_price_str=last_sale[i]
  market_price=int(market_price_str)
  meta_data = fd.get_income_statement_quarterly(symbol=symbol)
  net_income_str=income_statement['netIncome'][0]
  net_income=int(net_income_str)
  eps=net_income/volume
  pe_ratio=market_price/eps
  pe_ratio_comparision.append(pe_ratio)
  i+=1

pe_ratio_comparision.sort()
pe_sum=0
for j in n:
  pe_sum= pe_sum+pe_ratio_comparision[i]
average_pe=pe_sum/n
cnt=0
z=0
recomend_pe=[]
while pe_ratio_comparision[cnt]< average_pe:
  recomend_pe[z]=pe_ratio_comparision[cnt]
  cnt=cnt+1
  z+=1

print('the stocks with less then average pe in the financial sector is:')
for j in cnt:
  print() 
print('the most recommended stock with the lowest pe ratio is :')
print(pe_ratio_comparision[0])
